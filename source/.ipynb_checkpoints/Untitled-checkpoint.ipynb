# %%
import re

num = []
with open('./temp.txt') as file:
    for i in range(0, 900):
        line = file.readline()
        line_list = re.split(' ',line)
        if i % 6 == 0:
            print('-----------')
        print(float(line_list[-1]))
        
# for i in range(0,30):
#     if i % 6 == 0:
#         print('-----------')
#     print(num[i])
# Out:
# -----------
# 0.8379523964786436
# 0.8375122110061869
# 0.837406321277289
# 0.16194200065167808
# 0.8870962433381631
# 0.8376792698826596
# -----------
# 0.8354485776805252
# 0.8556844547563806
# 0.8599099099099099
# 0.16936936936936936
# 0.8963339014690366
# 0.8475027746947836
# -----------
# 0.8454288407163054
# 0.8449952933793536
# 0.8448979591836735
# 0.15447409733124018
# 0.8991832298672399
# 0.8451633165829147
# -----------
# 0.8443553774215097
# 0.8459731543624162
# 0.84633411449615
# 0.1560093739537998
# 0.8853648703583176
# 0.8453435880287578
# -----------
# 0.8116189662537378
# 0.8100297492562686
# 0.8095440988495952
# 0.18789944610140605
# 0.8680353982429408
# 0.810580204778157
# -----------
# 0.809559653744825
# 0.7998541742617572
# 0.7966666666666666
# 0.1874074074074074
# 0.8572028806584363
# 0.803061414971066
# -----------
# 0.7890295358649789
# 0.7866108786610879
# 0.7857142857142857
# 0.21008403361344538
# 0.8533398653579078
# 0.7873684210526316
# -----------
# ...
